# %%
#scrape
import urllib.request
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/Gila_monster')
html = response.read()
"scraped data: ", html
# Out:
# ('scraped data: ',
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html.parser')
raw_text = soup.get_text(strip = True)
raw_text
# Out:
# 'Gila monster - WikipediaGila monsterFrom Wikipedia, the free encyclopediaJump to navigationJump to searchLargest living species of lizard in the United StatesGila monsterConservation statusNear Threatened(IUCN 3.1)[1]CITESAppendix II(CITES)[2]Scientific classificationKingdom:AnimaliaPhylum:ChordataClass:ReptiliaOrder:SquamataFamily:HelodermatidaeGenus:HelodermaSpecies:H.\xa0suspectumBinomial nameHeloderma suspectumCope, 1869A Gila monsterTheGila monster(Heloderma suspectum,/ˈhiːlə/HEE-lə) is a species ofvenomouslizardnative to theSouthwestern United Statesand the northwesternMexicanstate ofSonora. It is a heavy, typically slow-moving reptile, up to 56 centimetres (22\xa0in) long, and it is the only venomous lizard native to the United States. Its venomous close relatives, the fourbeaded lizards(all former subspecies ofHeloderma horridum) inhabit Mexico and Guatemala.[3][4]The Gila monster is sluggish in nature, so it is not generally dangerous and very rarely poses a real threat to 
# ...

# %%
stopWords = []
with open('stopwords.txt') as f:
    stopWords = f.readlines()

#REMOVE NEWLINE IN FROM THE STOPWORD LIST
stopWordList = [data.strip() for data in stopWords]
stopWordList
# Out:
# ['a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'among',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyone',
#  'anything',
#  'anywhere',
#  'are',
#  'area',
#  'areas',
#  'around',
#  'as',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'at',
#  'away',
#  'b',
#  'back',
#  'backed',
#  'backing',
#  'backs',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'been',
#  'before',
#  'began',
#  'behind',
#  'being',
#  'beings',
#  'best',
#  'better',
#  'between',
#  'big',
#  'both',
#  'but',
#  'by',
#  'c',
#  'came',
#  'can',
#  'cannot',
#  'case',
#  'cases',
#  'certain',
#  'certainly',
#  'clear',
#  'clearly',
#  'come',
#  'could',
#  'd',
#  'did',
#  'differ',
#  'different',
#  'differently',
#  'do',
#  'does',
#  'done',
#  'down',
#  'down',
#  'downed',
#  'downing',
#  'downs',
# ...

# %%
tokens = []
tokens = raw_text.split()
tokens
# Out:
# ['Gila',
#  'monster',
#  '-',
#  'WikipediaGila',
#  'monsterFrom',
#  'Wikipedia,',
#  'the',
#  'free',
#  'encyclopediaJump',
#  'to',
#  'navigationJump',
#  'to',
#  'searchLargest',
#  'living',
#  'species',
#  'of',
#  'lizard',
#  'in',
#  'the',
#  'United',
#  'StatesGila',
#  'monsterConservation',
#  'statusNear',
#  'Threatened(IUCN',
#  '3.1)[1]CITESAppendix',
#  'II(CITES)[2]Scientific',
#  'classificationKingdom:AnimaliaPhylum:ChordataClass:ReptiliaOrder:SquamataFamily:HelodermatidaeGenus:HelodermaSpecies:H.',
#  'suspectumBinomial',
#  'nameHeloderma',
#  'suspectumCope,',
#  '1869A',
#  'Gila',
#  'monsterTheGila',
#  'monster(Heloderma',
#  'suspectum,/ˈhiːlə/HEE-lə)',
#  'is',
#  'a',
#  'species',
#  'ofvenomouslizardnative',
#  'to',
#  'theSouthwestern',
#  'United',
#  'Statesand',
#  'the',
#  'northwesternMexicanstate',
#  'ofSonora.',
#  'It',
#  'is',
#  'a',
#  'heavy,',
#  'typically',
#  'slow-moving',
#  'reptile,',
#  'up',
#  'to',
#  '56',
# ...

# %%
tokens1 = []
tokens1 = raw_text.split()
tokens = []
for word in tokens1:
    tokens.append(re.sub('[^A-Za-z]+', ' ', word))

while(" " in tokens):
    tokens.remove(" ")

tokens
# Out:
# ['Gila',
#  'monster',
#  'WikipediaGila',
#  'monsterFrom',
#  'Wikipedia ',
#  'the',
#  'free',
#  'encyclopediaJump',
#  'to',
#  'navigationJump',
#  'to',
#  'searchLargest',
#  'living',
#  'species',
#  'of',
#  'lizard',
#  'in',
#  'the',
#  'United',
#  'StatesGila',
#  'monsterConservation',
#  'statusNear',
#  'Threatened IUCN',
#  ' CITESAppendix',
#  'II CITES Scientific',
#  'classificationKingdom AnimaliaPhylum ChordataClass ReptiliaOrder SquamataFamily HelodermatidaeGenus HelodermaSpecies H ',
#  'suspectumBinomial',
#  'nameHeloderma',
#  'suspectumCope ',
#  ' A',
#  'Gila',
#  'monsterTheGila',
#  'monster Heloderma',
#  'suspectum hi l HEE l ',
#  'is',
#  'a',
#  'species',
#  'ofvenomouslizardnative',
#  'to',
#  'theSouthwestern',
#  'United',
#  'Statesand',
#  'the',
#  'northwesternMexicanstate',
#  'ofSonora ',
#  'It',
#  'is',
#  'a',
#  'heavy ',
#  'typically',
#  'slow moving',
#  'reptile ',
#  'up',
#  'to',
#  'centimetres',
#  'in ',
#  'long ',
# ...

# %% [markdown]
# Remove stop words from your parsed article

# %%
for word in list(tokens):  # iterating on a copy since removing will mess things up
    if word in stopWordList:
        tokens.remove(word)
tokens
# Out:
# ['Gila',
#  'monster',
#  'WikipediaGila',
#  'monsterFrom',
#  'Wikipedia ',
#  'free',
#  'encyclopediaJump',
#  'navigationJump',
#  'searchLargest',
#  'living',
#  'species',
#  'lizard',
#  'United',
#  'StatesGila',
#  'monsterConservation',
#  'statusNear',
#  'Threatened IUCN',
#  ' CITESAppendix',
#  'II CITES Scientific',
#  'classificationKingdom AnimaliaPhylum ChordataClass ReptiliaOrder SquamataFamily HelodermatidaeGenus HelodermaSpecies H ',
#  'suspectumBinomial',
#  'nameHeloderma',
#  'suspectumCope ',
#  ' A',
#  'Gila',
#  'monsterTheGila',
#  'monster Heloderma',
#  'suspectum hi l HEE l ',
#  'species',
#  'ofvenomouslizardnative',
#  'theSouthwestern',
#  'United',
#  'Statesand',
#  'northwesternMexicanstate',
#  'ofSonora ',
#  'It',
#  'heavy ',
#  'typically',
#  'slow moving',
#  'reptile ',
#  'centimetres',
#  'in ',
#  'long ',
#  'venomous',
#  'lizard',
#  'native',
#  'United',
#  'States ',
#  'Its',
#  'venomous',
#  'close',
#  'relatives ',
# ...

# %% [markdown]
# CALCULATE AND DISPLAY THE TOP WORD COUNT

# %%
setList = list(set(tokens)) 
my_dict = {i:tokens.count(i) for i in setList}

tokenTopWord = max(my_dict, key=my_dict.get)
tokenTopWordCount = my_dict[tokenTopWord]

print(tokenTopWord," : ",tokenTopWordCount)
# Out:
# Gila  :  90

# %% [markdown]
# Display the longest word in your article

# %%
lengthOfLongestWord = len(tokens[0])
longestWord = tokens[0]
for words in tokens:
    if(len(words) > lengthOfLongestWord):
        lengthOfLongestWord = len(words)
        longestWord = words
        
print("Longest Word : ", longestWord,
", Word : ", lengthOfLongestWord)
# Out:
# Longest Word :  suspectumADW Heloderma suspectumARKive heloderma suspectumBioLib CoL KGXZEoL EPPO HLDMSUFossilworks GBIF iNaturalist IRMNG ITIS IUCN NatureServe NCBI RD suspectumSpecies uBio Retrieved , Word :  184

# %% [markdown]
# Rank all words by frequency

# %%
#for i in sorted(my_dict.values()):
    #print(i)

WordFreq = sorted(my_dict.items(), key=lambda x: x[1], reverse=True)
WordFreq
# Out:
# [('Gila', 90),
#  ('monster', 51),
#  (' V ', 36),
#  ('monitor', 34),
#  ('The', 23),
#  ('lizard', 18),
#  ('monsters', 17),
#  ('original', 14),
#  ('venom', 13),
#  ('maint ', 12),
#  ('authors', 12),
#  ('Monster', 11),
#  ('CS ', 10),
#  ('D ', 10),
#  ('monster s', 10),
#  ('beaded', 10),
#  ('bite', 9),
#  (' Heloderma', 9),
#  ('species', 9),
#  ('lizards', 9),
#  ('names ', 8),
#  ('multiple', 8),
#  (' The', 8),
#  ('M ', 8),
#  ('body', 7),
#  ('C ', 7),
#  ('It', 7),
#  ('water', 7),
#  ('list', 7),
#  (' Gila', 6),
#  ('human', 6),
#  ('United', 6),
#  ('A ', 6),
#  ('suspectum ', 6),
#  ('Heloderma', 6),
#  ('million', 5),
#  ('October', 5),
#  ('behavior', 5),
#  ('activity', 5),
#  ('observed', 5),
#  ('F ', 5),
#  ('monster ', 5),
#  ('May', 5),
#  ('New', 5),
#  ('time', 5),
#  ('book ', 5),
#  ('They', 5),
#  ('journal ', 5),
#  ('found', 5),
#  ('Retrieved ', 5),
#  ('venomous', 5),
#  (' H ', 5),
#  ('in ', 4),
#  (' about', 4),
#  ('breath', 4),
# ...

# %% [markdown]
# How many instances of each word

# %%
sorted(my_dict.items(), key=lambda x: x[1])
# Out:
# [('Wild', 1),
#  ('squirrels ', 1),
#  ('suspectum hi l HEE l ', 1),
#  (' link Schwandt ', 1),
#  ('Vi tWinaray Edit', 1),
#  ('season citation', 1),
#  ('distribution', 1),
#  ('cut', 1),
#  ('Man ', 1),
#  ('nail', 1),
#  ('minutes', 1),
#  ('Dohm ', 1),
#  ('differentiation', 1),
#  ('southeast', 1),
#  ('bengalensis Black spotted', 1),
#  ('linksThis', 1),
#  ('areas ', 1),
#  ('Academic', 1),
#  ('anictitating', 1),
#  ('panoptes Yemen', 1),
#  (' https en wikipedia org w index php title Gila monster oldid Categories IUCN',
#   1),
#  ('pushing', 1),
#  ('Palo', 1),
#  ('stud ', 1),
#  ('otherrodents ', 1),
#  ('June', 1),
#  ('allowing', 1),
#  ('black blue', 1),
#  ('Steve ', 1),
#  ('land', 1),
#  ('Matthew', 1),
#  ('dumerilii Emerald', 1),
#  ('vasoactive', 1),
#  ('stay', 1),
#  ('death', 1),
#  ('leap', 1),
#  ('High Lonesome', 1),
#  ('abrupt', 1),
#  ('team s', 1),
#  ('believed', 1),
#  ('Said', 1),
#  ('puddles', 1),
#  ('drawing', 1),
#  ('thatHelodermais', 1),
# ...

# %% [markdown]
# Read in posWords / negWords (I/O)

# %%
positiveWords = []
with open('positivewords.txt') as f:
    positiveWords = f.readlines()

#REMOVE NEWLINE IN FROM THE STOPWORD LIST
positiveWords = [data.strip() for data in positiveWords]
positiveWords
# Out:
# ['a+',
#  'abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'acclamation',
#  'accolade',
#  'accolades',
#  'accommodative',
#  'accomodative',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'achievible',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'adorable',
#  'adore',
#  'adored',
#  'adorer',
#  'adoring',
#  'adoringly',
#  'adroit',
#  'adroitly',
#  'adulate',
#  'adulation',
#  'adulatory',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affability',
#  'affable',
#  'affably',
#  'affectation',
#  'affection',
# ...

# %%
negativeWords = []
with open('negativewords.txt') as f:
    negativeWords = f.readlines()

#REMOVE NEWLINE IN FROM THE STOPWORD LIST
negativeWords = [data.strip() for data in negativeWords]
negativeWords
# Out:
# ['2-faced',
#  '2-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
# ...

# %% [markdown]
# Count the num times a pos vs. neg word come up in article sentiment

# %%
positiveWordsCount = 0
negativeWordsCount = 0
for word in list(tokens):  # iterating on a copy since removing will mess things up
    if word in positiveWords:
        positiveWordsCount +=1
    if word in negativeWords:
        negativeWordsCount +=1
        
        
print("Positive Words : ",positiveWordsCount)
print("Negative Words : ",negativeWordsCount)

if (positiveWordsCount > negativeWordsCount):
    print("Sentiment Analysis : Positive")
else:
    print("Sentiment Analysis : Negative")
# Out:
# Positive Words :  44
# Negative Words :  146
# Sentiment Analysis : Negative
